# %% [markdown]
# # DC Optimal Power Flow

# %% [markdown]
# ### Problem 5.1.
# This is a continuation of Problem 4.2 from Lecture 4.
# Let us assume now that we are in an hour with an excess of wind generation in Denmark and a deficit
# in other countries so that the power injection pi of the different countries is as follows:
# Germany= - 2 MW, DK1=5 MW, DK2=6 MW, Norway = - 8 MW, Sweden = -1 MW,
# Determine the voltage angles θi and the flows pl in the lines of the network. Assume that θ0=0; i.e. the
# reference bus is at node 0 (Germany); and the reactance in all links is xl=1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Parameters
p_GE = -2 # MW
p_DK1 = 5 # MW
p_DK2 = 6 # MW
p_NO = -8 # MW
p_SE = -1 # MW
